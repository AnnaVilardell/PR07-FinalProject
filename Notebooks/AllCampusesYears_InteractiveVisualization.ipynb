# %% [markdown]
# # Interactive visualization
#
# **Index**
#
# - [Environment](#Environment)
#
#
# - [Visualization](#Visualization)
#     - xx
#     - xx

# %% [markdown]
# ## Environment

# %% [markdown]
# #### Import libraries

# %%
# Pandas and Numpy
import pandas as pd
import numpy as np

# Maths
import math
from scipy import stats

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Interactive visualization
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Import data

# %%
apps_selCols = pd.read_csv("apps_allYears_clean_selCols.csv")

# %%
apps_addCols = pd.read_csv("apps_allYears_clean_selCols_addCols.csv")

# %%
apps_selCols.head()
# Out:
#   Bootcamp Course Bootcamp Format  Bootcamp Year Bootcamp Start Date  \
# 0              WD              FT           2018          2018-01-22
# 1              UX              FT           2018          2018-10-22
# 2              UX              FT           2018          2018-08-20
# 3              WD              FT           2020          2020-08-17
# 4              WD              PT           2018          2018-11-06
#
#   Campus - Timezone Created Date  Close Date        Stage  \
# 0               MEX   2017-09-11  2017-12-30  Closed lost
# 1               AMS   2018-07-17  2018-08-25  Closed lost
# 2               BCN   2018-01-05  2018-05-28  Closed lost
# 3               MIA   2020-07-14  2020-07-14  Closed lost
# 4               MIA   2017-09-11  2018-10-04  Closed lost
#
#    Discount Amount (converted)  Scholarship Amount (converted)  \
# 0                         0.00                             0.0
# 1                         0.00                             0.0
# ...

# %%
apps_addCols.head()
# Out:
#   Bootcamp Course Bootcamp Format  Bootcamp Year Campus - Timezone  Drop  \
# 0              WD              FT           2018               MEX     0
# 1              UX              FT           2018               AMS     0
# 2              UX              FT           2018               BCN     0
# 3              WD              FT           2020               MIA     0
# 4              WD              PT           2018               MIA     0
#
#      Drop Reason how did you hear about us? Person Account: Gender  \
# 0  Not specified               Social Media                   Male
# 1  Not specified                     google                   Male
# 2  Not specified                     google                   Male
# 3  Not specified               Social Media                 Female
# 4  Not specified                      other                   Male
#
#    Stage Duration  Paid Deposit  Scholarship  Discount  \
# 0          1125.0             0            0         0
# ...

# %% [markdown]
# # Visualizations

# %%
import plotly.express as px

fig = px.funnel(apps_selCols, x='Bootcamp Course', y='Bootcamp Year', color='Person Account: Gender')
fig.show()
# Out:
# <div>                            <div id="13694063-96b5-4f7d-978f-97fc5a125c42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13694063-96b5-4f7d-978f-97fc5a125c42")) {                    Plotly.newPlot(                        "13694063-96b5-4f7d-978f-97fc5a125c42",                        [{"hovertemplate": "Person Account: Gender=Male<br>Bootcamp Course=%{x}<br>Bootcamp Year=%{y}<extra></extra>", "legendgroup": "Male", "marker": {"color": "#636efa"}, "name": "Male", "orientation": "v", "showlegend": true, "type": "funnel", "x": ["WD", "UX", "UX", "WD", "UX", "WD", "UX", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "UX", "WD", "WD", "WD", "UX", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "WD", "DA", "WD", "WD", "UX", "WD", 
# ...
